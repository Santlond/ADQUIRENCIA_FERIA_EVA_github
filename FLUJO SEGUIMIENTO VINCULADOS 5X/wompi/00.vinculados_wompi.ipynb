# %% [markdown]
# FLUJO PARA LA EXTRACION DE LOS COMERCIOS VINCULADOS DE WOMPI CON SU TRANSACCIONALIDAD PARA LA MEDICION DE 5X

# %%
# ejecución total 

from sparky_bc import Sparky
import json
import pyodbc
import numpy as np

# %%
usuario= "daramire"

# %%
with open("C:/Users/" + usuario + "/Documents/archivoPass.json") as file:
    opt_srvr = json.load(file)

# %%
h=Sparky(dsn=opt_srvr["DSN"],username=opt_srvr["user"], password = opt_srvr["password"], hostname = "sbmdeblze003.bancolombia.corp")
# Out:
# 2025-10-01 15:45:38 - [WARNING] - No se encontro la carpeta "c:\Users\daramire\Documents\FLUJO SEGUIMIENTO VINCULADOS 5X\wompi\logs" para guardar los logs
#  ____  _____ __  __  ___ _____ _____
# |  _ \| ____|  \/  |/ _ \_   _| ____|
# | |_) |  _| | |\/| | | | || | |  _|
# |  _ <| |___| |  | | |_| || | | |___
# |_| \_\_____|_|  |_|\___/ |_| |_____|
#
#  ____  ____   _    ____  _  __
# / ___||  _ \ / \  |  _ \| |/ /
# \___ \| |_) / _ \ | |_) | ' /
#  ___) |  __/ ___ \|  _ <| . \
# |____/|_| /_/   \_\_| \_\_|\_\

# %%
parametros = {}
parametros["zona_p"] = 'proceso_consumidores'
parametros["zona_i"] = 'proceso_consumidores'
parametros["zona_f"] = 'proceso_enmascarado'
parametros['WCOM'] = h.helper.obtener_ultima_ingestion(tabla="resultados_wompi.wompi_merchants")
parametros['WBP'] = h.helper.obtener_ultima_ingestion(tabla="resultados_wompi.wompi_businesses_procedures")
parametros['MDM'] = h.helper.obtener_ultima_ingestion(tabla="resultados_fcr.fcr_mdm_datos_generales_clientes")
parametros['WTRX'] = h.helper.obtener_ultima_ingestion(tabla="resultados_wompi.wompi_transactions")
parametros['PCO'] = h.helper.obtener_ultima_ingestion(tabla="resultados_vspc_canales.tiplantaac")
parametros['PLTN'] = h.helper.obtener_ultima_ingestion(tabla="resultados_vspc_canales.fco_planta_comercial")
parametros
# Out:
# 2025-10-01 15:45:44 - [INFO] - Buscando fechas para resultados_wompi.wompi_merchants
# 2025-10-01 15:45:44 - [INFO] - Transcurrido: 1759351544, Tiempo de Refresco = 1000
# c:\Users\daramire\Documents\FLUJO SEGUIMIENTO VINCULADOS 5X\.venv\lib\site-packages\helper\helper.py:476: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(query, cn)
# 2025-10-01 15:45:46 - [INFO] - Finalizo la busqueda, duracion: 00:02.1, resultado: {'year': 2025, 'month': 10, 'day': 1}
# 2025-10-01 15:45:46 - [INFO] - Buscando fechas para resultados_wompi.wompi_businesses_procedures
# c:\Users\daramire\Documents\FLUJO SEGUIMIENTO VINCULADOS 5X\.venv\lib\site-packages\helper\helper.py:476: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(query, cn)
# 2025-10-01 15:45:46 - [INFO] - Finalizo la busqueda, duracion: 00:00.7, resultado: {'year': 2025, 'month': 10, 'day': 1}
# 2025-10-01 15:45:46 - [INFO] - Buscando fechas para resultados_fcr.fcr_mdm_datos_generales_clientes
# c:\Users\daramire\Documents\FLUJO SEGUIMIENTO VINCULADOS 5X\.venv\lib\site-packages\helper\helper.py:476: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(query, cn)
# 2025-10-01 15:45:50 - [INFO] - Finalizo la busqueda, duracion: 00:03.4, resultado: {'year': 2025, 'month': 9, 'day': 30}
# 2025-10-01 15:45:50 - [INFO] - Buscando fechas para resultados_wompi.wompi_transactions
# c:\Users\daramire\Documents\FLUJO SEGUIMIENTO VINCULADOS 5X\.venv\lib\site-packages\helper\helper.py:476: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(query, cn)
# 2025-10-01 15:45:52 - [INFO] - Finalizo la busqueda, duracion: 00:01.6, resultado: {'year': 2025, 'month': 9, 'day': 30}
# 2025-10-01 15:45:52 - [INFO] - Buscando fechas para resultados_vspc_canales.tiplantaac
# c:\Users\daramire\Documents\FLUJO SEGUIMIENTO VINCULADOS 5X\.venv\lib\site-packages\helper\helper.py:476: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(query, cn)
# c:\Users\daramire\Documents\FLUJO SEGUIMIENTO VINCULADOS 5X\.venv\lib\site-packages\helper\helper.py:476: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(query, cn)
# c:\Users\daramire\Documents\FLUJO SEGUIMIENTO VINCULADOS 5X\.venv\lib\site-packages\helper\helper.py:476: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(query, cn)
# 2025-10-01 15:46:18 - [INFO] - Finalizo la busqueda, duracion: 00:26.8, resultado: {'year': 2025, 'month': 9, 'day': 19}
# 2025-10-01 15:46:18 - [INFO] - Buscando fechas para resultados_vspc_canales.fco_planta_comercial
# c:\Users\daramire\Documents\FLUJO SEGUIMIENTO VINCULADOS 5X\.venv\lib\site-packages\helper\helper.py:476: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(query, cn)
# c:\Users\daramire\Documents\FLUJO SEGUIMIENTO VINCULADOS 5X\.venv\lib\site-packages\helper\helper.py:476: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(query, cn)
# c:\Users\daramire\Documents\FLUJO SEGUIMIENTO VINCULADOS 5X\.venv\lib\site-packages\helper\helper.py:476: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(query, cn)
# 2025-10-01 15:46:32 - [INFO] - Finalizo la busqueda, duracion: 00:13.5, resultado: {'year': 2025, 'month': 10, 'day': 1}
# {'zona_p': 'proceso_consumidores',
#  'zona_i': 'proceso_consumidores',
#  'zona_f': 'proceso_enmascarado',
#  'WCOM': {'year': 2025, 'month': 10, 'day': 1},
#  'WBP': {'year': 2025, 'month': 10, 'day': 1},
#  'MDM': {'year': 2025, 'month': 9, 'day': 30},
#  'WTRX': {'year': 2025, 'month': 9, 'day': 30},
#  'PCO': {'year': 2025, 'month': 9, 'day': 19},
#  'PLTN': {'year': 2025, 'month': 10, 'day': 1}}

# %%
h.helper.ejecutar_archivo("01.Tabla_comercios_wompi.sql",  params=parametros)

# %%
h.helper.ejecutar_archivo("02.transacciones_wompi.sql",  params=parametros)

# %%
h.helper.ejecutar_archivo("03.mastro_wompi_vinculados.sql",  params=parametros)

# %%
h.helper.ejecutar_archivo("04.vinculados_accion_comercial.sql",  params=parametros)

# %%
h.helper.ejecutar_archivo("05.vinculaciones_bpo_autogestion.sql",  params=parametros)

# %%
h.helper.ejecutar_archivo("10.final_wompi.sql",  params=parametros)
