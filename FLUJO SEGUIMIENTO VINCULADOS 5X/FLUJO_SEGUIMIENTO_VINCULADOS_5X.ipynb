# %% [markdown]
# FLUJO PARA LA EXTRACION DE LOS COMERCIOS VINCULADOS DE WOMPI CON SU TRANSACCIONALIDAD PARA LA MEDICION DE 5X

# %%
# ejecución total 
from sparky_bc import Sparky
import json
import pyodbc
import numpy as np

# %%
usuario= "daramire" ### No olvidar cambiar el usuario de la persona q lo vaya a ejecutar

# %%
with open("C:/Users/" + usuario + "/Documents/archivoPass.json") as file:
    opt_srvr = json.load(file)

# %%
h=Sparky(dsn=opt_srvr["DSN"],username=opt_srvr["user"], password = opt_srvr["password"], hostname = "sbmdeblze003.bancolombia.corp")
# Out:
# 2025-10-02 08:02:23 - [INFO] - Guardado logs en: c:\Users\daramire\Documents\FLUJO SEGUIMIENTO VINCULADOS 5X\logs\20251002_080223_remote_spark.log
#  ____  _____ __  __  ___ _____ _____
# |  _ \| ____|  \/  |/ _ \_   _| ____|
# | |_) |  _| | |\/| | | | || | |  _|
# |  _ <| |___| |  | | |_| || | | |___
# |_| \_\_____|_|  |_|\___/ |_| |_____|
#
#  ____  ____   _    ____  _  __
# / ___||  _ \ / \  |  _ \| |/ /
# \___ \| |_) / _ \ | |_) | ' /
#  ___) |  __/ ___ \|  _ <| . \
# |____/|_| /_/   \_\_| \_\_|\_\

# %%
# %run adquirencia/00.vinculados_adquirencia.ipynb

# %%
# %run wompi/00.vinculados_wompi.ipynb
# Out:
# c:\Users\daramire\Documents\FLUJO SEGUIMIENTO VINCULADOS 5X\.venv\lib\site-packages\nbformat\__init__.py:96: MissingIDFieldWarning: Cell is missing an id field, this will become a hard error in future nbformat versions. You may want to use `normalize()` on your notebooks before validations (available since nbformat 5.1.4). Previous versions of nbformat are fixing this issue transparently, and will stop doing so in the future.
#   validate(nb)
# 2025-10-02 08:48:31 - [INFO] - Guardado logs en: c:\Users\daramire\Documents\FLUJO SEGUIMIENTO VINCULADOS 5X\logs\20251002_084831_remote_spark.log
#  ____  _____ __  __  ___ _____ _____
# |  _ \| ____|  \/  |/ _ \_   _| ____|
# | |_) |  _| | |\/| | | | || | |  _|
# |  _ <| |___| |  | | |_| || | | |___
# |_| \_\_____|_|  |_|\___/ |_| |_____|
#
#  ____  ____   _    ____  _  __
# / ___||  _ \ / \  |  _ \| |/ /
# \___ \| |_) / _ \ | |_) | ' /
#  ___) |  __/ ___ \|  _ <| . \
# |____/|_| /_/   \_\_| \_\_|\_\
# 2025-10-02 08:48:31 - [INFO] - Buscando fechas para resultados_wompi.wompi_merchants
# 2025-10-02 08:48:31 - [INFO] - Transcurrido: 1759412911, Tiempo de Refresco = 1000
# c:\Users\daramire\Documents\FLUJO SEGUIMIENTO VINCULADOS 5X\.venv\lib\site-packages\helper\helper.py:476: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(query, cn)
# 2025-10-02 08:48:31 - [INFO] - Finalizo la busqueda, duracion: 00:00.1, resultado: {'year': 2025, 'month': 10, 'day': 1}
# 2025-10-02 08:48:31 - [INFO] - Buscando fechas para resultados_wompi.wompi_businesses_procedures
# c:\Users\daramire\Documents\FLUJO SEGUIMIENTO VINCULADOS 5X\.venv\lib\site-packages\helper\helper.py:476: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(query, cn)
# 2025-10-02 08:48:31 - [INFO] - Finalizo la busqueda, duracion: 00:00.0, resultado: {'year': 2025, 'month': 10, 'day': 1}
# 2025-10-02 08:48:31 - [INFO] - Buscando fechas para resultados_fcr.fcr_mdm_datos_generales_clientes
# c:\Users\daramire\Documents\FLUJO SEGUIMIENTO VINCULADOS 5X\.venv\lib\site-packages\helper\helper.py:476: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(query, cn)
# 2025-10-02 08:48:31 - [INFO] - Finalizo la busqueda, duracion: 00:00.1, resultado: {'year': 2025, 'month': 10, 'day': 1}
# 2025-10-02 08:48:31 - [INFO] - Buscando fechas para resultados_wompi.wompi_transactions
# c:\Users\daramire\Documents\FLUJO SEGUIMIENTO VINCULADOS 5X\.venv\lib\site-packages\helper\helper.py:476: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(query, cn)
# 2025-10-02 08:48:32 - [INFO] - Finalizo la busqueda, duracion: 00:00.5, resultado: {'year': 2025, 'month': 9, 'day': 30}
# 2025-10-02 08:48:32 - [INFO] - Buscando fechas para resultados_vspc_canales.tiplantaac
# c:\Users\daramire\Documents\FLUJO SEGUIMIENTO VINCULADOS 5X\.venv\lib\site-packages\helper\helper.py:476: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(query, cn)
# c:\Users\daramire\Documents\FLUJO SEGUIMIENTO VINCULADOS 5X\.venv\lib\site-packages\helper\helper.py:476: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(query, cn)
# c:\Users\daramire\Documents\FLUJO SEGUIMIENTO VINCULADOS 5X\.venv\lib\site-packages\helper\helper.py:476: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(query, cn)
# 2025-10-02 08:48:37 - [INFO] - Finalizo la busqueda, duracion: 00:05.5, resultado: {'year': 2025, 'month': 9, 'day': 19}
# 2025-10-02 08:48:37 - [INFO] - Buscando fechas para resultados_vspc_canales.fco_planta_comercial
# c:\Users\daramire\Documents\FLUJO SEGUIMIENTO VINCULADOS 5X\.venv\lib\site-packages\helper\helper.py:476: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(query, cn)
# c:\Users\daramire\Documents\FLUJO SEGUIMIENTO VINCULADOS 5X\.venv\lib\site-packages\helper\helper.py:476: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(query, cn)
# c:\Users\daramire\Documents\FLUJO SEGUIMIENTO VINCULADOS 5X\.venv\lib\site-packages\helper\helper.py:476: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(query, cn)
# 2025-10-02 08:48:41 - [INFO] - Finalizo la busqueda, duracion: 00:03.6, resultado: {'year': 2025, 'month': 10, 'day': 1}
# ---------------------------------------------------------------------------------------------
#                                 01.Tabla_comercios_wompi.sql
# ---------------------------------------------------------------------------------------------
#   i   tipo                    nombre                     estado     hora_inicio   duracion
# ---------------------------------------------------------------------------------------------
#  1/3    DROP ...umidores.plink_comercios_wompi_cincox   finalizado   08:48:41 AM     00:00.1
#  2/3  CREATE ...umidores.plink_comercios_wompi_cincox   finalizado   08:48:41 AM     00:08.6
#  3/3 COMPUTE ...umidores.plink_comercios_wompi_cincox   finalizado   08:48:50 AM     00:01.5
# ---------------------------------------------------------------------------------------------
#
# Resumen de consultas:
# -------------------------------------------------
#          documento            total    duracion
# -------------------------------------------------
#  01.Tabla_comercios_wompi.sql      3     00:10.3
# -------------------------------------------------
#
# ---------------------------------------------------------------------------------------------
#                                  02.transacciones_wompi.sql
# ---------------------------------------------------------------------------------------------
#   i   tipo                    nombre                     estado     hora_inicio   duracion
# ---------------------------------------------------------------------------------------------
#  4/6    DROP ...ores.plink_comercios_wompi_cincox_trx   finalizado   08:48:51 AM     00:00.1
#  5/6  CREATE ...ores.plink_comercios_wompi_cincox_trx   ejecutando   08:48:52 AM
